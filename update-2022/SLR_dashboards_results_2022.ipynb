# %%
# -*- coding: utf-8 -*-
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 20)

import numpy as np

from scipy import stats

from bokeh.io import show, output_file, export_png
from bokeh.plotting import figure
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.transform import factor_cmap
from bokeh.palettes import Category20b
from bokeh.models import LabelSet
import math

output_notebook()
# Out:
# /Users/andreavazquez/opt/anaconda3/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
sheet_id = "1R-8IiE7ZjDWMQ2olysYYPChvw-aarJzs"
sheet_name = "Final_papers"
url = "https://docs.google.com/spreadsheets/d/{0}/gviz/tq?tqx=out:csv&sheet={1}".format(sheet_id, sheet_name)
df = pd.read_csv(url)

# %%
df.head()
# Out:
#                                                Title  \
# 0      Integrated model-driven dashboard development
# 1  Exploration views: Understanding dashboard cre...
# 2  The TDAQ Analytics Dashboard: a real-time web ...
# 3  A Semantic Dashboard Description Language for ...
# 4  A customisable dashboard display for environme...
#
#                                              Authors  Year  \
# 0  Palpanas, T.; Chowdhary, P.; Mihaila, G.; Pine...  2007
# 1                          Elias, M.; Bezerianos, A.  2011
# 2            Miotto, G.L.; Magnoni, L.; Sloper, J.E.  2011
# 3                                          Kintz, M.  2012
# 4    Filonik D., Medland R., Foth M., Rittenbruch M.  2013
#
#                               DOI  \
# 0       10.1007/s10796-007-9032-9
# 1    10.1007/978-3-642-23768-3_23
# 2  10.1088/1742-6596/331/2/022019
# 3                             NaN
# 4     10.1007/978-3-642-37157-8_8
#
#   Type of publication (Journal, Book, Conference proceedings, etc)  \
# 0                                            Article
# 1                                   Conference Paper
# 2                                   Conference Paper
# 3                                   Conference Paper
# 4                                   Conference Paper
#
#                         Source (name of publication)  \
# 0                      Information Systems Frontiers
# 1  Lecture Notes in Computer Science (including s...
# 2  INTERNATIONAL CONFERENCE ON COMPUTING IN HIGH ...
# 3                          CEUR Workshop Proceedings
# 4  Lecture Notes in Computer Science (including s...
#
#                                             Keywords  \
# 0  Model-driven development, Dashboard, Business ...
# 1  synchronized views, interface customization, n...
# 2                                                  -
# 3  Dashboards, business processes, monitoring, co...
# 4  energy monitoring, environmental sustainabilit...
#
#   Variability factors (factors that affect the dashboard composition)  \
# 0                                   Business process
# 1                                   User preferences
# 2                                   User preferences
# 3                            Business process, goals
# 4                                   User preferences
#
#   Application domain                                 Method  ...  \
# 0                 BI                           Model Driven  ...
# 1                 BI  Configuration wizard + visual mapping  ...
# 2            Physics                   Configuration wizard  ...
# 3                 BI                           Model Driven  ...
# 4  Energy monitoring                   Configuration wizard  ...
#
#   Generative approach? (applicable to those solutions that need a pre-configuration)  \
# 0                                                Yes
# 1                                                NaN
# 2                                                NaN
# 3                                                Yes
# 4                                                NaN
#
#        First level classification  \
# 0                    Personalized
# 1  Customizable w/ system support
# 2                    Customizable
# 3                    Personalized
# 4                    Customizable
#
#                              Detailed classification Unnamed: 19 Unnamed: 20  \
# 0                        Personalized (model-driven)         NaN         NaN
# 1  Assisted customization + personalized recommen...         NaN         NaN
# 2                         Customizable (user-driven)         NaN         NaN
# 3  Personalized (goal-driven) (with customization...         NaN         NaN
# 4                         Customizable (user-driven)         NaN         NaN
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24  Unnamed: 25
# 0         NaN         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN         NaN          NaN
# 2         NaN         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN         NaN          NaN
# 4         NaN         NaN         NaN         NaN          NaN
#
# [5 rows x 26 columns]

# %%
print("Number of papers resulting the SLR: ", len(df))
# Out:
# Number of papers resulting the SLR:  30

# %%
keywords = df["Keywords"].dropna().astype('str').values
keywords_list = []
for keyword in keywords:
    [keywords_list.append(x.strip().lower()) for x in keyword.split(';')]
    
keywords_list = [x for x in keywords_list if x != '']
dfKeywords = pd.DataFrame(keywords_list)

# %%
dfKeywords
# Out:
#                                                     0
# 0   model-driven development, dashboard, business ...
# 1   synchronized views, interface customization, n...
# 2                                                   -
# 3   dashboards, business processes, monitoring, co...
# 4   energy monitoring, environmental sustainabilit...
# 5   internet of things, device cloud, remote user ...
# 6   on-line analytical processing, adaptive dashbo...
# 7   variability, data visualisation, sensors, mode...
# 8   emergency management, information visualizatio...
# 9   web apis, semantic annotation, monitoring envi...
# 10  microservices, microservice monitoring, micros...
# 11  data analytics, mobile applications analytics,...
# 12  business processes, monitoring, dashboards, ro...
# 13                                                  -
# 14                                                  -
# 15  learning analytic dashboard, dashboard generat...
# 16  dashboard design, bussiness intelligence, smal...
# 17  system monitoring, operations monitoring, real...
# 18  interactive data exploration and discovery, da...
# 19                    visualization, user interaction
# 20                                                  -
# 21  data analytics, dashboard, flexible, customiza...
# 22  spl, dsl, domain engineering, dashboards, empl...
# 23                                 dynamic dashboards
# 24                             semantic web of things
# 25                                       industry 4.0
# 26                                   fleet monitoring
# 27                                       ssn ontology
# 28                                    web thing model
# 29  dashboards, domain-specific language, internet...
# 30  monitoring dashboard, dashboard generation, cl...
# 31                                     data analytics
# 32                              business intelligence
# 33                                          dashboard
# 34                                        star schema
# 35     interactive data summarization and exploration
# 36                   grouping and aggregation queries
# 37                                      user feedback
# 38                          multi-armed bandits (mab)
# 39  aesthetics, dashboard, generator, usability gu...
# 40  data visualization, fake news, machine learnin...

# %%
dfKeywords.columns = ['Term']

# %%
resultsKeywords = pd.DataFrame(dfKeywords['Term'].value_counts())
resultsKeywords
# Out:
#                                                     Term
# -                                                      4
# data analytics                                         1
# star schema                                            1
# internet of things, device cloud, remote user i...     1
# aesthetics, dashboard, generator, usability gui...     1
# semantic web of things                                 1
# interactive data summarization and exploration         1
# model-driven development, dashboard, business p...     1
# on-line analytical processing, adaptive dashboa...     1
# monitoring dashboard, dashboard generation, clo...     1
# variability, data visualisation, sensors, model...     1
# spl, dsl, domain engineering, dashboards, emplo...     1
# multi-armed bandits (mab)                              1
# data analytics, dashboard, flexible, customizab...     1
# emergency management, information visualization...     1
# data visualization, fake news, machine learning...     1
# system monitoring, operations monitoring, real-...     1
# industry 4.0                                           1
# dashboard design, bussiness intelligence, small...     1
# fleet monitoring                                       1
# visualization, user interaction                        1
# energy monitoring, environmental sustainability...     1
# ssn ontology                                           1
# data analytics, mobile applications analytics, ...     1
# synchronized views, interface customization, no...     1
# microservices, microservice monitoring, microse...     1
# learning analytic dashboard, dashboard generato...     1
# user feedback                                          1
# interactive data exploration and discovery, dat...     1
# dashboards, domain-specific language, internet ...     1
# dynamic dashboards                                     1
# grouping and aggregation queries                       1
# business processes, monitoring, dashboards, rol...     1
# web thing model                                        1
# business intelligence                                  1
# web apis, semantic annotation, monitoring envir...     1
# dashboard                                              1
# dashboards, business processes, monitoring, con...     1

# %%
resultsKeywords.reset_index(inplace=True)
resultsKeywords.columns = ['Term', 'Count']

resultsKeywords
# Out:
#                                                  Term  Count
# 0                                                   -      4
# 1                                      data analytics      1
# 2                                         star schema      1
# 3   internet of things, device cloud, remote user ...      1
# 4   aesthetics, dashboard, generator, usability gu...      1
# 5                              semantic web of things      1
# 6      interactive data summarization and exploration      1
# 7   model-driven development, dashboard, business ...      1
# 8   on-line analytical processing, adaptive dashbo...      1
# 9   monitoring dashboard, dashboard generation, cl...      1
# 10  variability, data visualisation, sensors, mode...      1
# 11  spl, dsl, domain engineering, dashboards, empl...      1
# 12                          multi-armed bandits (mab)      1
# 13  data analytics, dashboard, flexible, customiza...      1
# 14  emergency management, information visualizatio...      1
# 15  data visualization, fake news, machine learnin...      1
# 16  system monitoring, operations monitoring, real...      1
# 17                                       industry 4.0      1
# 18  dashboard design, bussiness intelligence, smal...      1
# 19                                   fleet monitoring      1
# 20                    visualization, user interaction      1
# 21  energy monitoring, environmental sustainabilit...      1
# 22                                       ssn ontology      1
# 23  data analytics, mobile applications analytics,...      1
# 24  synchronized views, interface customization, n...      1
# 25  microservices, microservice monitoring, micros...      1
# 26  learning analytic dashboard, dashboard generat...      1
# 27                                      user feedback      1
# 28  interactive data exploration and discovery, da...      1
# 29  dashboards, domain-specific language, internet...      1
# 30                                 dynamic dashboards      1
# 31                   grouping and aggregation queries      1
# 32  business processes, monitoring, dashboards, ro...      1
# 33                                    web thing model      1
# 34                              business intelligence      1
# 35  web apis, semantic annotation, monitoring envi...      1
# 36                                          dashboard      1
# 37  dashboards, business processes, monitoring, co...      1

# %%
# output_file('vbar.html')

p = figure(x_range=resultsKeywords['Term'].tolist(), plot_width=1250, toolbar_location=None, title="Keywords Counts")
p.vbar(x=resultsKeywords['Term'].tolist(), top=resultsKeywords['Count'].tolist(), width=0.3, color='#4BACC5')
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 9
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
#   <div class="bk-root" id="000ea8dc-1855-48f8-9526-e3c336820a2b" data-root-id="1002"></div>

# %%
authors = df["Authors"].values
authors_list = []
for author in authors:
    [authors_list.append(x.strip()) for x in author.split(';')]
    
authors_list = [x for x in authors_list if x != '']

dfAuthors = pd.DataFrame(authors_list)
dfAuthors.columns = ['Name']

# %%
resultsAuthors = pd.DataFrame(dfAuthors['Name'].value_counts())
resultsAuthors.reset_index(inplace=True)
resultsAuthors.columns = ['Name', 'Count']
resultsAuthors
# Out:
#                                                Name  Count
# 0                               Vázquez-Ingelmo, A.      2
# 1                              García-Peñalvo, F.J.      2
# 2                                        Theron, R.      2
# 3                                    Van Hoecke, S.      2
# 4                                         Kintz, M.      2
# 5                                    Noonpakdee, W.      1
# 6                                    de Walle, R.V.      1
# 7                                      R. Weinreich      1
# 8                                       Riveill, M.      1
# 9                                         Elias, M.      1
# 10                                        Pinel, F.      1
# 11                                       Michel, C.      1
# 12                                       Chua, G.G.      1
# 13                                   Bederson, B.B.      1
# 14                                       Mosser, S.      1
# 15                                       Arjun,, S.      1
# 16                                          May, M.      1
# 17                                     Bouarour, N.      1
# 18                                     Janssens, O.      1
# 19                                   Verstichel, S.      1
# 20                                      Magnoni, L.      1
# 21                               García-Holgado, A.      1
# 22                                 Van Herwegen, J.      1
# 23                                        Soare, M.      1
# 24                                       Barros, R.      1
# 25                                          Guo, S.      1
# 26                                      Cabrera, C.      1
# 27                                         B. Mayer      1
# 28                                    Gilliot, J.M.      1
# 29                                     Hautte, S.V.      1
# 30                                        Kumar, K.      1
# 31                                  Kochanowski, M.      1
# 32                                      Ciucanu, R.      1
# 33                                      Koetter, F.      1
# 34                                   Bezerianos, A.      1
# 35                                  Majstorović, B.      1
# 36  Filonik D., Medland R., Foth M., Rittenbruch M.      1
# 37                                     Bastidas, V.      1
# 38                                        Tundo, A.      1
# 39                                  Pastushenko, O.      1
# 40                                  Vivacqua, A. S.      1
# 41                                        Rojas, E.      1
# 42                                      Correia, H.      1
# 43                                      Ongenae, F.      1
# 44                                     Elmqvist, N.      1
# 45                                        Moens, P.      1
# 46                                    Rodrigues, P.      1
# 47                                      Furtado, V.      1
# 48                                     Sloper, J.E.      1
# 49                                   Amer-Yahia, S.      1
# 50                                     Verborgh, R.      1
# 51                                      Mobilio, M.      1
# 52                                      Soni, S. K.      1
# 53                                    Riganelli, O.      1
# 54                                       Collet, P.      1
# 55                                       Lavoue, E.      1
# 56                                     Garlatti, S.      1
# 57                                 Steenwinckel, B.      1
# 58                                 Min Chim Lim, P.      1
# 59                                       Da Col, S.      1
# 60                                 Khunkornsiri, T.      1
# 61                                       Kukolj, S.      1
# 62                                         Bose, J.      1
# 63                                        Mak, M.T.      1
# 64                                  Radovanović, S.      1
# 65                                       George, S.      1
# 66                                  Sousa Pinto, J.      1
# 67                                      Mariani, L.      1
# 68                                      Cardoso, A.      1
# 69                                      Karstens E.      1
# 70                                 Triantafillou A.      1
# 71                                         Belo, O.      1
# 72                                       Hruška, T.      1
# 73                                    Chowdhary, P.      1
# 74                                     Siong Ng, W.      1
# 75                                     Pinheiro, P.      1
# 76                                     Palpanas, T.      1
# 77                                      Mihaila, G.      1
# 78                                       Santos, H.      1
# 79                                   Castelnovo, C.      1
# 80                                         Huys, C.      1
# 81                                     Yalcin, M.A.      1
# 82                              Chua Zhen Liang, D.      1
# 83                                       Dantas, V.      1
# 84                                Nascimento, B. S.      1
# 85                            Vieira Teixeira, C.J.      1
# 86                                        Hynek, J.      1
# 87                                     De Paepe, D.      1
# 88                                       Chan, A.L.      1
# 89                                     Miotto, G.L.      1
# 90                                           Ji, M.      1
# 91                                 McGuinness, D.L.      1
# 92                          Orlovskyi, D., Kopp, A.      1
# 93                                      Dabbebi, I.      1
# 94                                 Borges, M. R. S.      1
# 95                                        Iksal, S.      1
# 96                                       Petasis G.      1
# 97                                        Logre, I.      1
# 98                                   Danaisawat, K.      1
# 99                                   Phothichai, A.      1

# %%
p = figure(x_range=resultsAuthors['Name'].tolist(), plot_width=990, toolbar_location=None, title="Authors Counts")
p.vbar(x=resultsAuthors['Name'].tolist(), top=resultsAuthors['Count'].tolist(), width=0.3, color='#900E3F')
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 4
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
#   <div class="bk-root" id="b65429e8-0f6c-4fa8-83bc-6ac1254b2544" data-root-id="1087"></div>

# %%
resultsYears = pd.DataFrame(df['Year'].value_counts())
resultsYears.reset_index(inplace=True)
resultsYears.columns = ['Year', 'Count']
resultsYears.sort_values(['Year', 'Count'], ascending=[False, False], inplace=True)
resultsYears
# Out:
#     Year  Count
# 2   2021      4
# 4   2020      3
# 6   2019      2
# 1   2018      5
# 0   2017      6
# 7   2016      2
# 3   2014      3
# 8   2013      1
# 9   2012      1
# 5   2011      2
# 10  2007      1

# %%
x = resultsYears['Year'].astype('str').tolist() + ['2015', '2010', '2009', '2008']
x.sort()
p = figure(x_range=x, plot_width=600, plot_height=400, toolbar_location=None, title="Papers per year")
p.vbar(x=resultsYears['Year'].astype('str').tolist(), top=resultsYears['Count'].astype('int').tolist(), color='#900E3F', width=0.9)
p.xgrid.grid_line_color = None
p.yaxis[0].ticker.desired_num_ticks = 7
p.y_range.start = 0
p.y_range.end = 6.5

show(p)
# Out:
#   <div class="bk-root" id="b4bef746-0c68-4d6e-9fa2-9c7ff2aac60f" data-root-id="1180"></div>

# %%
resultsType = pd.DataFrame(df['Type of publication (Journal, Book, Conference proceedings, etc)'].value_counts())
resultsType.reset_index(inplace=True)
resultsType.columns = ['Type', 'Count']
resultsType.sort_values(['Type', 'Count'], ascending=[False, False], inplace=True)
resultsType
# Out:
#                Type  Count
# 0  Conference Paper     21
# 1           Article      9

# %%
p = figure(x_range=resultsType['Type'].tolist(), plot_width=600, plot_height=600, title="Publication type")
p.vbar(x=resultsType['Type'].tolist(), top=resultsType['Count'].tolist(), width=0.9, color='#900E3F')
p.xgrid.grid_line_color = None
p.yaxis[0].ticker.desired_num_ticks = 10
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="31194506-7424-47a5-8d4a-30f545c1806a" data-root-id="1282"></div>

# %%
variability = df["Variability factors (factors that affect the dashboard composition)"].values
variability_list = []
for v in variability:
    print(v)
    [variability_list.append(x.strip().lower().capitalize()) for x in v.split(',')]
    
variability_list = [x for x in variability_list if x != '']

dfVariability = pd.DataFrame(variability_list)
dfVariability.columns = ['Name']

resultsVariability = pd.DataFrame(dfVariability['Name'].value_counts())
resultsVariability.reset_index(inplace=True)
resultsVariability.columns = ['Name', 'Count']
resultsVariability.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
resultsVariability
# Out:
# Business process
# User preferences
# User preferences
# Business process, goals
# User preferences
# Data source
# Usage profiles
# User preferences
# User preferences
# User profile
# User preferences
# User preferences
# User role
# Data structure, user preferences
# User preferences
# User profile, data structure, analysis scenario
# User preferences, guidelines
# User preferences
# Data structure, user preferences
# User abilities
# Data structure
# User preferences
# User preferences
# User preferences
# User preferences
# User preferences
# Data structure
# Data structure, user preferences
# User preferences, guidelines
# User preferences
#                  Name  Count
# 7   Analysis scenario      1
# 3    Business process      2
# 8         Data source      1
# 1      Data structure      6
# 9               Goals      1
# 2          Guidelines      2
# 5      Usage profiles      1
# 6      User abilities      1
# 0    User preferences     20
# 4        User profile      2
# 10          User role      1

# %%
p = figure(x_range=resultsVariability['Name'].astype('str').tolist(), plot_width=800, plot_height=500, title="Variability factors")
p.vbar(x=resultsVariability['Name'].astype('str').tolist(), top=resultsVariability['Count'].astype('int').tolist(), width=0.5, color='#900E3F')
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/3.8
p.yaxis[0].ticker.desired_num_ticks = 12
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="3607a833-0ce2-4130-b452-f99bed449515" data-root-id="1392"></div>

# %%
resultsDomain = pd.DataFrame(df['Application domain'].value_counts())
resultsDomain.reset_index(inplace=True)
resultsDomain.columns = ['Name', 'Count']
resultsDomain.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
resultsDomain
# Out:
#                         Name  Count
# 0                         BI      9
# 11             Communication      1
# 7        Disaster situations      1
# 12                 Economics      1
# 6       Emergency management      1
# 9          Energy monitoring      1
# 3                    Generic      2
# 10      Interface evaluation      1
# 1                        IoT      4
# 4         Learning Analytics      2
# 5   Microservices monitoring      1
# 8                    Physics      1
# 14         Sensor monitoring      1
# 2        Services monitoring      3
# 13           Social Sciences      1

# %%
p = figure(x_range=resultsDomain['Name'].astype('str').tolist(), plot_width=600, plot_height=500, title="Application domain")
p.vbar(x=resultsDomain['Name'].astype('str').tolist(), top=resultsDomain['Count'].astype('int').tolist(), width=0.5, color='#900E3F')
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/4
p.xaxis.major_label_text_font_size = "9pt"
p.yaxis[0].ticker.desired_num_ticks = 12
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="4448b44a-9365-4694-9167-83e2c8d2ad51" data-root-id="1510"></div>

# %%
method = df["Method"].values
method_list = []
for m in method:
    [method_list.append(x.strip().lower().capitalize()) for x in m.split(',')]
    
method_list = [x for x in method_list if x != '']

dfMethod = pd.DataFrame(method_list)
dfMethod.columns = ['Name']

resultsMethod = pd.DataFrame(dfMethod['Name'].value_counts())
resultsMethod.reset_index(inplace=True)
resultsMethod.columns = ['Name', 'Count']
resultsMethod.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
resultsMethod
# Out:
#                                        Name  Count
# 5                                    Agents      2
# 2                       Configuration files      4
# 0                      Configuration wizard      6
# 3     Configuration wizard + visual mapping      4
# 9            Generator with models as input      1
# 8                  Inclusive user modelling      1
# 12  Knowledge graphs and indicator ontology      1
# 10                         Machine learning      1
# 1                              Model driven      5
# 11                    Pre-defined templates      1
# 6                         Semantic reasoner      2
# 4                                       Spl      3
# 7                            Visual mapping      1

# %%
p = figure(x_range=resultsMethod['Name'].astype('str').tolist(), plot_width=600, plot_height=500, title="Variability methods")
p.vbar(x=resultsMethod['Name'].astype('str').tolist(), top=resultsMethod['Count'].astype('int').tolist(), width=0.5, color='#900E3F')
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/4
p.yaxis[0].ticker.desired_num_ticks = 12
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="3b3be90d-b51e-475e-966d-53366d510a31" data-root-id="1636"></div>

# %%
target = df["Target of the variability process"].values
target_list = []
for t in target:
    [target_list.append(x.strip().lower().capitalize()) for x in t.split(',')]
    
target_list = [x for x in target_list if x != '']

dfTarget = pd.DataFrame(target_list)
dfTarget.columns = ['Name']

resultsTarget = pd.DataFrame(dfTarget['Name'].value_counts())
resultsTarget.reset_index(inplace=True)
resultsTarget.columns = ['Name', 'Count']
resultsTarget.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
resultsTarget
# Out:
#                        Name  Count
# 2              Data sources     13
# 4             Functionality      1
# 3                      Kpis     13
# 1                    Layout     20
# 5             Visual design      1
# 0  Visualization components     27

# %%
p = figure(x_range=resultsTarget['Name'].astype('str').tolist(), plot_width=600, plot_height=500, title="Target of the variability process")
p.vbar(x=resultsTarget['Name'].astype('str').tolist(), top=resultsTarget['Count'].astype('int').tolist(), width=0.5, color='#900E3F')
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/4
p.xaxis.major_label_text_font_size = "10pt"
p.yaxis[0].ticker.desired_num_ticks = 12
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="8fafcb58-9e6b-46f4-b57b-3c4af077edf7" data-root-id="1770"></div>

# %%
stage = df["Stage at which the variation / customization / personalization is performed"].values
stage_list = []
for s in stage:
    [stage_list.append(x.strip().lower().capitalize()) for x in s.split(',')]
    
stage_list = [x for x in stage_list if x != '']

dfStage = pd.DataFrame(stage_list)
dfStage.columns = ['Name']

resultsStage = pd.DataFrame(dfStage['Name'].value_counts())
resultsStage.reset_index(inplace=True)
resultsStage.columns = ['Name', 'Count']
resultsStage.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
resultsStage
# Out:
#                  Name  Count
# 3        Compile-time      1
# 0   Pre-configuration     13
# 2            Run-time      8
# 1  User-configuration      9

# %%
p = figure(x_range=resultsStage['Name'].astype('str').tolist(), plot_width=600, plot_height=500, title="Stage at which the variability process is applied")
p.vbar(x=resultsStage['Name'].astype('str').tolist(), top=resultsStage['Count'].astype('int').tolist(), width=0.5, color='#900E3F')
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/4
p.xaxis.major_label_text_font_size = "12pt"
p.yaxis[0].ticker.desired_num_ticks = 12
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="71f25acd-84a3-43c1-a3eb-0b54cd89744d" data-root-id="1912"></div>

# %%
resultsTest = pd.DataFrame(df['Tested in real-world scenario?'].value_counts())
resultsTest.reset_index(inplace=True)
resultsTest.columns = ['Name', 'Count']
resultsTest.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
resultsTest
# Out:
#       Name  Count
# 2       No      6
# 1  Partial     11
# 0      Yes     13

# %%
p = figure(x_range=resultsTest['Name'].astype('str').tolist(), plot_width=600, plot_height=500, title="Solution tested in real-world scenario?")
p.vbar(x=resultsTest['Name'].astype('str').tolist(), top=resultsTest['Count'].astype('int').tolist(), width=0.5, color='#900E3F')
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/4
p.xaxis.major_label_text_font_size = "12pt"
p.yaxis[0].ticker.desired_num_ticks = 12
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="398f3927-ba1e-469c-8b2a-fb46426d81d3" data-root-id="2062"></div>

# %%
resultsClassification = pd.DataFrame(df['First level classification'].value_counts())
resultsClassification.reset_index(inplace=True)
resultsClassification.columns = ['Name', 'Count']
resultsClassification.sort_values(['Count', 'Name'], ascending=[False, True], inplace=True)
resultsClassification
# Out:
#                              Name  Count
# 0                    Customizable     14
# 1  Customizable w/ system support      5
# 2                          Hybrid      4
# 3                    Personalized      4
# 4                        Adaptive      3

# %%
p = figure(x_range=resultsClassification['Name'].astype('str').tolist(), plot_height=500, plot_width=800, title="Solutions' classification")
p.vbar(x=resultsClassification['Name'].astype('str').tolist(), top=resultsClassification['Count'].astype('int').tolist(), width=0.9, color='#900E3F')
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 15
p.x_range.range_padding = 0.1

show(p)
# Out:
#   <div class="bk-root" id="212bb41c-6d10-4d05-88ae-fcd94d9e678a" data-root-id="2220"></div>
